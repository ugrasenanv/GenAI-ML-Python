# %% [markdown]
# # Python Programming - Example Set 3: Functions and Classes
#
# This notebook demonstrates advanced programming concepts including functions, classes, file operations, and exception handling.

# %% [markdown]
# ## Example 13: Function Examples

# %%
# Function to print first 10 natural numbers
def first_ten():
    for i in range(1, 11):
        print(i, end=" ")
    print()  # New line

if __name__ == "__main__":
    first_ten()

# %%
# Function to calculate sum of first 10 natural numbers
def sum_first_ten():
    sum_total = 0
    for i in range(1, 11):
        sum_total += i
    return sum_total

if __name__ == "__main__":
    print(sum_first_ten())

# %%
# Function to reverse a number
def reverse_number(num):
    reverse_num = 0
    while num > 0:
        digit = num % 10
        reverse_num = (reverse_num * 10) + digit
        num //= 10
    return reverse_num

if __name__ == "__main__":
    try:
        num = int(input("Enter the number:"))
        result = reverse_number(num)
        print(f"Number is {num} and Reverse number is {result}")
    except ValueError:
        print("Enter a numeric value")

# %% [markdown]
# ## Example 14: Calculator Functions

# %%
# Calculator using functions
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        return "Error: Cannot divide by zero."
    return x / y

def calculator():
    print("Select an operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")

    choice = input("Enter choice (1/2/3/4): ")

    if choice in ('1', '2', '3', '4'):
        try:
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))
        except ValueError:
            print("Invalid input. Please enter numerical values.")
            return

        if choice == '1':
            print(f"Result: {add(num1, num2)}")
        elif choice == '2':
            print(f"Result: {subtract(num1, num2)}")
        elif choice == '3':
            print(f"Result: {multiply(num1, num2)}")
        elif choice == '4':
            print(f"Result: {divide(num1, num2)}")
    else:
        print("Invalid selection.")

if __name__ == "__main__":
    calculator()

# %% [markdown]
# ## Example 15: File Operations

# %%
# Create a text file and store student details
def write_students_to_file(filename):
    student_details = [
        "ID: 1 | Name: Alice | Grade: A",
        "ID: 2 | Name: Bob   | Grade: B",
        "ID: 3 | Name: Carol | Grade: A+"
    ]

    with open(filename, "w") as file:
        for student in student_details:
            file.write(student + "\n")

    print(f"Student details successfully saved to {filename}")

write_students_to_file("students.txt")

# %%
# Read data from a file
def read_file_contents(filename):
    try:
        with open(filename, "r") as file:
            data = file.read()
            print(f"--- Contents of {filename} ---")
            print(data)
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")

read_file_contents("students.txt")

# %% [markdown]
# ## Example 16: Exception Handling

# %%
# Handle division by zero using exception handling
def safe_divide(numerator, denominator):
    try:
        result = numerator / denominator
        print(f"{numerator} divided by {denominator} is: {result}")
    except ZeroDivisionError:
        print("Exception Caught: Attempted to divide by zero! Please provide a non-zero denominator.")

# Testing the function
print("Test 1 (Valid):")
safe_divide(10, 2)

print("\nTest 2 (Division by Zero):")
safe_divide(5, 0)

# %% [markdown]
# ## Example 17: Object-Oriented Programming

# %%
# Create a Student class with name and marks
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks
    
    def display_details(self):
        print(f"Student Name: {self.name}")
        print(f"Marks Secured: {self.marks}")
        print("-" * 25)

# Creating instances (objects) of the Student class
student1 = Student("Alice", 95)
student2 = Student("Bob", 78)

# Calling the display method on the objects
print("Student Records:")
student1.display_details()
student2.display_details()
